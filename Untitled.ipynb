# %% [markdown]
# # importing libraries

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import openpyxl

# %% [markdown]
# # Creating excel sheet

# %%
excel=openpyxl.Workbook()
excel1=openpyxl.Workbook()
excel2=openpyxl.Workbook()
excel3=openpyxl.Workbook()
excel1.sheetnames
Sheet=excel.active
Sheet1=excel1.active
Sheet2=excel2.active
Sheet3=excel3.active

# %%
Sheet.append(['Team1','Team2','Winner','Margin','Ground','Match Date','Scorecard'])

# %% [markdown]
# # Extracting data using requests and Beatifulsoup for result report

# %%
url = 'https://www.espncricinfo.com/records/season/team-match-results/2022to23-2022to23?trophy=89'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36"}

# %%
result = requests.get(url,headers=headers)

# %%
result # to check whether the page is active
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(result.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/CiIcons/ci-icons-v2.19/fonts/icomoon.woff?gencn3" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Bold/BentonSans-Bold.woff" rel="preload" type="font/woff"/><link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Regular/BentonSans-Regular.woff" rel="preload" type="font/woff"/><link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Medium/BentonSans-Medium.woff" rel="preload" type="font/woff"/><link crossorigin="anonymous" href="https://wassets.hscicdn.com" rel="preconnect"/><link crossorigin="anonymous" href="https://img1.hscicdn.com" rel="preconnect"/><script type="text/javascript">
#           /*! js-cookie v3.0.5 | MIT */
# ...

# %%
#tables = soup.find('di',attrs={'class':"ds-w-full ds-table ds-table-xs ds-table-auto  ds-w-full ds-overflow-scroll ds-scrollbar-hide"})
rows=soup.find('table').tbody.find_all('tr')

# %%
len(rows)
# Out:
# 42

# %%
scorecard_url=[]
scorecard_list=[]
dic1={}
summary_report=[]
for row in rows:
    dic1['team1'] = row.find('td',attrs={'class':'ds-min-w-max'}).span.text
    team = row.find_all('td',attrs={'class':'ds-min-w-max ds-text-right'})
    dic1['team2'] = team[0].text
    dic1['winner']=team[1].text
    dic1['margin']=team[2].text
    dic1['ground']=team[3].text
    dic1['match_date']=row.find('td',attrs={'class':'ds-min-w-max ds-text-right ds-whitespace-nowrap'}).span.text
    dic1['scorecard'] = team[4].span.text
    print(dic1)
    Sheet.append([team1,team2,winner,margin,ground,match_date,scorecard])
    scorecard_url.append(team[4].a['href'])
    scorecard_list.append(team[4].span.text)
    #print(scorecard_url)
    summary_report.append(dic1.copy())
    #print(team1,team2,winner,margin,ground,match_date,scorecard)
    #Sheet.append([team1,team2,winner,margin,ground,match_date,scorecard])
# Out:
# {'team1': 'Namibia', 'team2': 'Sri Lanka', 'winner': 'Namibia', 'margin': '55 runs', 'ground': 'Geelong (564)', 'match_date': 'Oct 16, 2022', 'scorecard': 'T20I # 1823'}
# {'team1': 'Netherlands', 'team2': 'U.A.E.', 'winner': 'Netherlands', 'margin': '3 wickets', 'ground': 'Geelong (564)', 'match_date': 'Oct 16, 2022', 'scorecard': 'T20I # 1825'}
# {'team1': 'Scotland', 'team2': 'West Indies', 'winner': 'Scotland', 'margin': '42 runs', 'ground': 'Hobart (905)', 'match_date': 'Oct 17, 2022', 'scorecard': 'T20I # 1826'}
# {'team1': 'Ireland', 'team2': 'Zimbabwe', 'winner': 'Zimbabwe', 'margin': '31 runs', 'ground': 'Hobart (905)', 'match_date': 'Oct 17, 2022', 'scorecard': 'T20I # 1828'}
# {'team1': 'Namibia', 'team2': 'Netherlands', 'winner': 'Netherlands', 'margin': '5 wickets', 'ground': 'Geelong (564)', 'match_date': 'Oct 18, 2022', 'scorecard': 'T20I # 1830'}
# ...

# %%
df2=pd.DataFrame(summary_report)
df2.head(42)
# Out:
#            team1         team2        winner      margin          ground  \
# 0        Namibia     Sri Lanka       Namibia     55 runs   Geelong (564)
# 1    Netherlands        U.A.E.   Netherlands   3 wickets   Geelong (564)
# 2       Scotland   West Indies      Scotland     42 runs    Hobart (905)
# 3        Ireland      Zimbabwe      Zimbabwe     31 runs    Hobart (905)
# 4        Namibia   Netherlands   Netherlands   5 wickets   Geelong (564)
# 5      Sri Lanka        U.A.E.     Sri Lanka     79 runs   Geelong (564)
# 6        Ireland      Scotland       Ireland   6 wickets    Hobart (905)
# 7    West Indies      Zimbabwe   West Indies     31 runs    Hobart (905)
# 8    Netherlands     Sri Lanka     Sri Lanka     16 runs   Geelong (564)
# 9        Namibia        U.A.E.        U.A.E.      7 runs   Geelong (564)
# 10       Ireland   West Indies       Ireland   9 wickets    Hobart (905)
# 11      Scotland      Zimbabwe      Zimbabwe   5 wickets    Hobart (905)
# ...

# %%
len(scorecard_url)
# Out:
# 42

# %%
import re

# %%
scorecard_list
# Out:
# ['T20I # 1823',
#  'T20I # 1825',
#  'T20I # 1826',
#  'T20I # 1828',
#  'T20I # 1830',
#  'T20I # 1832',
#  'T20I # 1833',
#  'T20I # 1834',
#  'T20I # 1835',
#  'T20I # 1836',
#  'T20I # 1837',
#  'T20I # 1838',
#  'T20I # 1839',
#  'T20I # 1840',
#  'T20I # 1841',
#  'T20I # 1842',
#  'T20I # 1843',
#  'T20I # 1844',
#  'T20I # 1845',
#  'T20I # 1846',
#  'T20I # 1847',
#  'T20I # 1848',
#  'T20I # 1849',
#  'T20I # 1850',
#  'T20I # 1851',
#  'T20I # 1852',
#  'T20I # 1853',
#  'T20I # 1855',
#  'T20I # 1856',
#  'T20I # 1858',
#  'T20I # 1859',
#  'T20I # 1860',
#  'T20I # 1861',
#  'T20I # 1862',
#  'T20I # 1864',
#  'T20I # 1867',
#  'T20I # 1871',
#  'T20I # 1872',
#  'T20I # 1873',
#  'T20I # 1877',
#  'T20I # 1878',
#  'T20I # 1879']

# %%
scorecard_url
# Out:
# ['/series/icc-men-s-t20-world-cup-2022-23-1298134/namibia-vs-sri-lanka-1st-match-first-round-group-a-1298135/full-scorecard',
#  '/series/icc-men-s-t20-world-cup-2022-23-1298134/netherlands-vs-united-arab-emirates-2nd-match-first-round-group-a-1298136/full-scorecard',
#  '/series/icc-men-s-t20-world-cup-2022-23-1298134/scotland-vs-west-indies-3rd-match-first-round-group-b-1298137/full-scorecard',
#  '/series/icc-men-s-t20-world-cup-2022-23-1298134/ireland-vs-zimbabwe-4th-match-first-round-group-b-1298138/full-scorecard',
#  '/series/icc-men-s-t20-world-cup-2022-23-1298134/namibia-vs-netherlands-5th-match-first-round-group-a-1298139/full-scorecard',
#  '/series/icc-men-s-t20-world-cup-2022-23-1298134/sri-lanka-vs-united-arab-emirates-6th-match-first-round-group-a-1298140/full-scorecard',
#  '/series/icc-men-s-t20-world-cup-2022-23-1298134/ireland-vs-scotland-7th-match-first-round-group-b-1298141/full-scorecard',
# ...

# %%
length = len(scorecard_url)
dic ={}
dic2={}
batting_list=[]
bowling_list=[]
df_length=len(df)
for i in range(length):
    #print(i)
    page= requests.get('https://www.espncricinfo.com/'+ scorecard_url[i])
    soup1 = BeautifulSoup(page.text,'html.parser')
    tables= soup1.find_all('table')
    s=0
    for j in [0,2]:
        #print('hi')
        #print(j)
        table = tables[j].find('tbody')
        #print(table)
        rows = table.find_all('tr',attrs={'class':''})
        l=0
        for row in rows:
            l+=1            
            dic['match']=scorecard_list[i]
            teams=soup1.find_all('span',class_='ds-text-title-xs ds-font-bold ds-capitalize')
            dic['teaminnings']=teams[s].text.strip()
            try:
                dic['battingrank']= l
                dic['batsman'] = row.find('td',class_ = re.compile('ds-w-0 ds-whitespace-nowrap ds-min-w-max ds-flex ds-items-center')).text
                dic['details'] = row.find('td',class_='ds-min-w-max !ds-pl-[100px]').text
                dic['runs']=row.find('td',attrs={'class':'ds-w-0 ds-whitespace-nowrap ds-min-w-max ds-text-right ds-text-typo'}).text
                td=row.find_all('td',attrs={'class':'ds-w-0 ds-whitespace-nowrap ds-min-w-max ds-text-right'})
                dic['balls']=td[0].text
                dic['fours']=td[2].text
                dic['sixes']=td[3].text
                dic['SR']=td[4].text
                #print(dic)
                batting_list.append(dic.copy())
                
            except AttributeError as e:
                None
        s+=1
        
    s=0
    for j in [1,3]:
        table = tables[j].find('tbody')
        rows = table.find_all('tr',attrs={'class':''}) 
        l=0
        for row in rows:
            l+=1
            dic2['match']=scorecard_list[i]
            teams=soup1.find_all('span',class_='ds-text-title-xs ds-font-bold ds-capitalize')
            dic2['teaminnings']=teams[s].text.strip()
            try:
                dic2['bowlingrank']= l
                dic2['bowler'] = row.find('td',class_ = re.compile('ds-flex ds-items-center')).text
                td=row.find_all('td',attrs={'class':'ds-w-0 ds-whitespace-nowrap ds-min-w-max ds-text-right'})
                dic2['overs']=td[0].text
                dic2['maiden']=td[1].text
                dic2['runs']=td[2].text
                dic2['wickets']=row.find('td',class_='ds-w-0 ds-whitespace-nowrap ds-text-right').span.strong.text
                dic2['economy']=td[3].text
                dic2['Wides']=td[7].text
                dic2['no_balls']=td[8].text
                bowling_list.append(dic2.copy())
                
            except AttributeError as e:
                None
            
        s+=1

# %%
import pandas as pd

# %%
df=pd.DataFrame(batting_list)
df.head(50)
# Out:
#           match           teaminnings  battingrank                    batsman  \
# 0   T20I # 1823               Namibia            1        Michael van Lingen
# 1   T20I # 1823               Namibia            2             Divan la Cock
# 2   T20I # 1823               Namibia            3    Jan Nicol Loftie-Eaton
# 3   T20I # 1823               Namibia            4             Stephan Baard
# 4   T20I # 1823               Namibia            5        Gerhard Erasmus (c)
# 5   T20I # 1823               Namibia            6              Jan Frylinck
# 6   T20I # 1823               Namibia            7               David Wiese
# 7   T20I # 1823               Namibia            8                   JJ Smit
# 8   T20I # 1823             Sri Lanka            1           Pathum Nissanka
# 9   T20I # 1823             Sri Lanka            2             Kusal Mendis †
# 10  T20I # 1823             Sri Lanka            3       Dhananjaya de Silva
# ...

# %%
df['out/not out'] = df['details'].apply(lambda x: 'out' if len(x)>8 else 'not out')

# %%
df.drop('details',axis=1,inplace=True)
df.head(30)
# Out:
#           match           teaminnings  battingrank                    batsman  \
# 0   T20I # 1823               Namibia            1        Michael van Lingen
# 1   T20I # 1823               Namibia            2             Divan la Cock
# 2   T20I # 1823               Namibia            3    Jan Nicol Loftie-Eaton
# 3   T20I # 1823               Namibia            4             Stephan Baard
# 4   T20I # 1823               Namibia            5        Gerhard Erasmus (c)
# 5   T20I # 1823               Namibia            6              Jan Frylinck
# 6   T20I # 1823               Namibia            7               David Wiese
# 7   T20I # 1823               Namibia            8                   JJ Smit
# 8   T20I # 1823             Sri Lanka            1           Pathum Nissanka
# 9   T20I # 1823             Sri Lanka            2             Kusal Mendis †
# 10  T20I # 1823             Sri Lanka            3       Dhananjaya de Silva
# ...

# %%
df1=pd.DataFrame(bowling_list)
df1.head(50)
# Out:
#           match           teaminnings  bowlingrank                bowler  \
# 0   T20I # 1823               Namibia            1    Maheesh Theekshana
# 1   T20I # 1823               Namibia            2   Dushmantha Chameera
# 2   T20I # 1823               Namibia            3       Pramod Madushan
# 3   T20I # 1823               Namibia            4   Chamika Karunaratne
# 4   T20I # 1823               Namibia            5     Wanindu Hasaranga
# 5   T20I # 1823             Sri Lanka            2           David Wiese
# 6   T20I # 1823             Sri Lanka            3       Bernard Scholtz
# 7   T20I # 1823             Sri Lanka            4          Ben Shikongo
# 8   T20I # 1823             Sri Lanka            5               JJ Smit
# 9   T20I # 1823             Sri Lanka            6          Jan Frylinck
# 10  T20I # 1825  United Arab Emirates            1         Fred Klaassen
# 11  T20I # 1825  United Arab Emirates            2           Tim Pringle
# ...

# %%
excel.save('Summary_report.xlsx')

# %% [markdown]
# # Writing to excel

# %%
df2.to_excel('summary_report.xlsx',index=False)

# %%
df.to_excel('Batting_summary.xlsx',index=False)

# %%
df1.to_excel('Bowling_Sumaary.xlsx',index=False)
